# %%
from IPython.display import Image
Image("logo-color.png")

# %%
# %%capture
# !pip3 install finalytics --upgrade

# %%
from finalytics import get_symbols
from finalytics import Ticker
from IPython.display import IFrame

# %% [markdown]
# ### SYMBOLS SEARCH

# %%
get_symbols("APPLE", "Equity")
# Out:
# {'3SAP.PA': 'GraniteShares 3x Short Apple Da',
#  'APC.F': 'APPLE INC.',
#  'AAPL': 'Apple Inc.',
#  'PEGY': 'Pineapple Energy Inc.',
#  '3LAP.PA': 'GraniteShares 3x Long Apple Dai',
#  'VC91.MU': 'PINEAPPLE ENERGY  DL-,05',
#  'APLE': 'Apple Hospitality REIT, Inc.',
#  'AAPLD.BA': 'APPLE INC CEDEAR(REPR 1/10 SHR)',
#  '0R2V.IL': 'APPLE INC APPLE ORD (CDI)',
#  'APC.DE': 'APPLE INC.',
#  'AAPL.BA': 'APPLE INC CEDEAR(REPR 1/10 SHR)',
#  'AAPL.VI': 'APPLE INC',
#  'MLP': 'Maui Land & Pineapple Company,',
#  'AT0000A2MBF8.VI': 'RCB BonZ/AlphabetAmazApple-23',
#  'VC91.DU': 'PINEAPPLE ENERGY  DL-,05',
#  'VC91.BE': 'PINEAPPLE ENERGY  DL-,05',
#  'AAPL.NE': 'APPLE CDR (CAD HEDGED)',
#  'APRU': 'APPLE RUSH COMPANY INC',
#  'US03784Y2000.SG': 'Apple Hospitality REIT Inc.',
#  'AAPL34.SA': 'APPLE       DRN',
#  'AAPL.MX': 'APPLE INC',
#  'PNPL': 'PINEAPPLE INC',
#  'AAPL.AS': 'LS 1x Apple Tracker ETP',
#  '1AAPL.MI': 'APPLE',
#  '603020.SS': 'APPLE FLAVOR & FRAGRANCE GROUP'}

# %%
get_symbols("S&P 500", "Index")
# Out:
# {'^SPXXMP': 'S&P 500 Ex-Materials',
#  '^SP5PAHET': 'S&P 500 Net Zero 2050 Paris-Ali',
#  '^SPDAUDT': 'S&P 500 Dividend Aristocrats (T',
#  '^SPSVHCT': 'S&P 500 Capped 35/20 Health Car',
#  '^SPXEHAET': 'S&P 500 ESG+ EUR Hedged Index T',
#  '^SPXETCT': 'S&P 500 ESG Tilted Index (CAD)',
#  '^SPXESQET': 'S&P 500 Equal Weight ESG Index',
#  '^SPX450UT': 'S&P 500 Communication Services',
#  '^SPXQHDUT': 'S&P 500 Quality High Dividend I',
#  '^SP5RR1UT': 'S&P 500 High Rate-Sensitivity 1',
#  '^SPXLTBUT': 'S&P 500 Low Volatility Target B',
#  '^SPVIXMT': 'S&P 500 VIX Mid-Term Index MCAP',
#  '^SPROME02': 'Cboe S&P 500 Buffer Protect Ind',
#  '^SPE5EVUT': 'S&P 500 ESG Enhanced Value Inde',
#  '^SPXEWCET': 'S&P 500 Equal Weight Index (EUR',
#  '^SP2BF10U': 'Cboe S&P 500 10% Buffered 25 Ju',
#  '^SPXQVMGN': 'S&P 500 Quality, Value & Moment',
#  '^SPXADF5T': 'S&P 500 Annual Dividend Futures',
#  '^SPXESMN': 'S&P 500 ESG Index (MXN) NTR',
#  '^SPPACSGT': 'S&P 500 Net Zero 2050 Paris-Ali',
# ...

# %% [markdown]
# ### SECURITY ANALYSIS

# %%
ticker = Ticker("AAPL")

# %%
ticker.get_current_price()
# Out:
# 186.4

# %%
ticker.get_summary_stats()
# Out:
# {'Symbol': 'AAPL',
#  'Name': 'Apple',
#  'Exchange': 'NasdaqGS',
#  'Currency': 'USD',
#  'Timestamp': 1699650001,
#  'Current Price': 186.4,
#  '24H Change': 2.3220046,
#  '24H Volume': 65934802.0,
#  '24H Open': 183.97,
#  '24H High': 186.565,
#  '24H Low': 183.53,
#  '24H Close': 182.17,
#  '52 Week High': 198.23,
#  '52 Week Low': 124.17,
#  '52 Week Change': 25.708115,
#  '50 Day Average': 176.474,
#  '200 Day Average': 172.53094,
#  'Trailing EPS': 6.13,
#  'Current EPS': 5.72,
#  'Forward EPS': 6.19,
#  'Trailing P/E': 30.40783,
#  'Current P/E': 32.587414,
#  'Forward P/E': 30.113085,
#  'Dividend Rate': 0.96,
#  'Dividend Yield': 0.52,
#  'Book Value': 3.997,
#  'Price to Book': 46.634975,
#  'Market Cap': 2899041845248.0,
#  'Shares Outstanding': 15552799744.0,
#  'Average Analyst Rating': '2.1 - Buy'}

# %%
ticker.get_price_history("2023-01-01", "2023-10-31", "1d")
# Out:
# shape: (208, 7)
# ┌──────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ timestamp    ┆ open       ┆ high       ┆ low        ┆ close      ┆ volume     ┆ adjclose   │
# │ ---          ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ datetime[ms] ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        │
# ╞══════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ 2023-01-03   ┆ 130.279999 ┆ 130.899994 ┆ 124.169998 ┆ 125.07     ┆ 1.121175e8 ┆ 124.374809 │
# │ 00:00:00     ┆            ┆            ┆            ┆            ┆            ┆            │
# │ 2023-01-04   ┆ 126.889999 ┆ 128.660004 ┆ 125.080002 ┆ 126.360001 ┆ 8.91136e7  ┆ 125.657639 │
# │ 00:00:00     ┆            ┆            ┆            ┆            ┆            ┆            │
# │ 2023-01-05   ┆ 127.129997 ┆ 127.769997 ┆ 124.760002 ┆ 125.019997 ┆ 8.09627e7  ┆ 124.325089 │
# ...

# %%
ticker.display_candlestick_chart("2023-01-01", "2023-11-10", "1d", "html")

# %%
IFrame("candlestick_chart.html", 1200, 1000)
# Out:
#         <iframe
#             width="1200"
#             height="1000"
#             src="candlestick_chart.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
ticker.get_options_chain()
# Out:
# shape: (1_537, 16)
# ┌────────────┬───────────┬──────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ expiration ┆ ttm       ┆ type ┆ contractSy ┆ … ┆ contractSi ┆ lastTradeD ┆ impliedVo ┆ inTheMone │
# │ ---        ┆ ---       ┆ ---  ┆ mbol       ┆   ┆ ze         ┆ ate        ┆ latility  ┆ y         │
# │ str        ┆ f64       ┆ str  ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆           ┆      ┆ str        ┆   ┆ str        ┆ datetime[m ┆ f64       ┆ bool      │
# │            ┆           ┆      ┆            ┆   ┆            ┆ s]         ┆           ┆           │
# ╞════════════╪═══════════╪══════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 2023-11-17 ┆ 0.164258  ┆ call ┆ AAPL231117 ┆ … ┆ REGULAR    ┆ 2023-11-09 ┆ 4.730473  ┆ true      │
# │            ┆           ┆      ┆ C00050000  ┆   ┆            ┆ 20:17:29   ┆           ┆           │
# ...

# %%
ticker.display_options_chart(0.02, "html")

# %%
IFrame("options_chart_0.html", 1200, 1000)
# Out:
#         <iframe
#             width="1200"
#             height="1000"
#             src="options_chart_0.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("options_chart_1.html", 1200, 1000)
# Out:
#         <iframe
#             width="1200"
#             height="1000"
#             src="options_chart_1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("options_chart_2.html", 1200, 1000)
# Out:
#         <iframe
#             width="1200"
#             height="1000"
#             src="options_chart_2.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
ticker.get_news("2023-11-01", "2023-11-09", False)
# Out:
# {0: {'Title': 'Apple Inc. stock underperforms Wednesday when compared to ... - MarketWatch',
#   'Source': 'MarketWatch',
#   'Link': 'https://news.google.com/rss/articles/CBMilAFodHRwczovL3d3dy5tYXJrZXR3YXRjaC5jb20vZGF0YS1uZXdzL2FwcGxlLWluYy1zdG9jay11bmRlcnBlcmZvcm1zLXdlZG5lc2RheS13aGVuLWNvbXBhcmVkLXRvLWNvbXBldGl0b3JzLWRlc3BpdGUtZGFpbHktZ2FpbnMtYjYzYmFkMWEtNTYyZmZlN2JiMmE20gEA?oc=5',
#   'Timestamp': 'Wed, 08 Nov 2023 21:32:00 GMT',
#   'Text': ' ',
#   'Sentiment Score': 0.0,
#   'Positive Score': 0.0,
#   'Negative Score': 0.0,
#   'Positive Keywords': [],
#   'Negative Keywords': []},
#  1: {'Title': 'What to look for when Apple (AAPL) reports Q4 2023 results on Nov. 2 - AlphaStreet',
#   'Source': 'AlphaStreet',
# ...

# %%
ticker.get_income_statement()
# Out:
# shape: (13, 6)
# ┌──────────────────────────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ Items                        ┆ 2022-09-30 ┆ 2022-12-31 ┆ 2023-03-31 ┆ 2023-06-30 ┆ 2023-09-30 │
# │ ---                          ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ str                          ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        │
# ╞══════════════════════════════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ Revenue                      ┆ 9.0146e10  ┆ 1.1715e11  ┆ 9.4836e10  ┆ 8.1797e10  ┆ 8.9498e10  │
# │ Cost of Goods Sold           ┆ 5.2051e10  ┆ 6.6822e10  ┆ 5.2860e10  ┆ 4.5384e10  ┆ 4.9071e10  │
# │ Gross Profit                 ┆ 3.8095e10  ┆ 5.0332e10  ┆ 4.1976e10  ┆ 3.6413e10  ┆ 4.0427e10  │
# │ Operating Expenses           ┆ 1.3201e10  ┆ 1.4316e10  ┆ 1.3658e10  ┆ 1.3415e10  ┆ 1.3458e10  │
# ...

# %%
ticker.get_balance_sheet()
# Out:
# shape: (21, 6)
# ┌──────────────────────────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ Items                        ┆ 2022-09-30 ┆ 2022-12-31 ┆ 2023-03-31 ┆ 2023-06-30 ┆ 2023-09-30 │
# │ ---                          ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ str                          ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        │
# ╞══════════════════════════════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ Cash and Cash Equivalents    ┆ 2.3646e10  ┆ 2.0535e10  ┆ 2.4687e10  ┆ 2.8408e10  ┆ 2.9965e10  │
# │ Accounts Receivable          ┆ 2.8184e10  ┆ 2.3752e10  ┆ 1.7936e10  ┆ 1.9549e10  ┆ 2.9508e10  │
# │ Inventories                  ┆ 4.9460e9   ┆ 6.8200e9   ┆ 7.4820e9   ┆ 7.3510e9   ┆ 6.3310e9   │
# │ Other Current Assets         ┆ 2.1223e10  ┆ 1.6422e10  ┆ 1.3660e10  ┆ 1.3640e10  ┆ 1.4695e10  │
# ...

# %%
ticker.get_cashflow_statement()
# Out:
# shape: (28, 6)
# ┌─────────────────────────────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ Items                           ┆ 2022-09-30 ┆ 2022-12-31 ┆ 2023-03-31 ┆ 2023-06-30 ┆ 2023-09-30 │
# │ ---                             ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ str                             ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        │
# ╞═════════════════════════════════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ Net Income from Continuing      ┆ 2.0721e10  ┆ 2.9998e10  ┆ 2.4160e10  ┆ 1.9881e10  ┆ 2.2956e10  │
# │ Opera…                          ┆            ┆            ┆            ┆            ┆            │
# │ Depreciation, Amortization, and ┆ 2.8650e9   ┆ 2.9160e9   ┆ 2.8980e9   ┆ 3.0520e9   ┆ 2.6530e9   │
# │ …                               ┆            ┆            ┆            ┆            ┆            │
# ...

# %%
ticker.get_financial_ratios()
# Out:
# shape: (21, 6)
# ┌─────────────────────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ Items                   ┆ 2022-09-30 ┆ 2022-12-31 ┆ 2023-03-31 ┆ 2023-06-30 ┆ 2023-09-30 │
# │ ---                     ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ str                     ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        │
# ╞═════════════════════════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ gross_profit_margin     ┆ 0.422592   ┆ 0.429623   ┆ 0.442617   ┆ 0.445163   ┆ 0.451708   │
# │ operating_profit_margin ┆ 0.276152   ┆ 0.307424   ┆ 0.2986     ┆ 0.281159   ┆ 0.301336   │
# │ net_profit_margin       ┆ 0.22986    ┆ 0.256056   ┆ 0.254756   ┆ 0.243053   ┆ 0.256497   │
# │ return_on_assets        ┆ 0.05874    ┆ 0.086513   ┆ 0.072736   ┆ 0.05934    ┆ 0.065108   │
# │ …                       ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          │
# ...

# %%
ticker.compute_performance_stats("2020-01-01", "2020-12-31", "1d", "^GSPC", 0.95, 0.02)
# Out:
# {'Symbol': 'AAPL',
#  'Benchmark': '^GSPC',
#  'Start Date': '2020-01-01',
#  'End Date': '2020-12-31',
#  'Interval': '1d',
#  'Confidence Level': 0.95,
#  'Risk Free Rate': 0.02,
#  'Daily Return': 0.27240403042198463,
#  'Daily Volatility': 2.9358068204400176,
#  'Total Return': 78.08556484545768,
#  'Annualized Return': 98.48133535688994,
#  'Annualized Volatility': 46.60448846526926,
#  'Alpha': -0.08919672319102599,
#  'Beta': 0.612559214001869,
#  'Sharpe Ratio': 2.0702155207387385,
#  'Sortino Ratio': 2.816711033630732,
#  'Active Return': 63.27413719079764,
#  'Active Risk': 26.375300310372776,
#  'Information Ratio': 2.398992104211736,
#  'Calmar Ratio': 3.9637458355988366,
#  'Maximum Drawdown': 24.845522251305383,
#  'Value at Risk': -4.5516439954160495,
#  'Expected Shortfall': -6.943011579064957,
#  'Security Prices': shape: (252,)
#  Series: '' [f64]
#  [
#  	75.087502
#  	74.357498
#  	74.949997
#  	74.597504
#  	75.797501
#  	77.407501
#  	77.582497
#  	79.239998
# ...

# %%
ticker.display_performance_chart("2023-01-01", "2023-11-10", "1d", "^GSPC", 0.95, 0.02, "html")

# %%
IFrame("performance_chart.html", 1200, 1000)
# Out:
#         <iframe
#             width="1200"
#             height="1000"
#             src="performance_chart.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
